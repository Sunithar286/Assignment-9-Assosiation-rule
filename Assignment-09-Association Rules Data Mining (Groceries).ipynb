# %% [markdown]
# # Assignment-09-Association Rules Data Mining (Groceries)

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13660/1838924838.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from mlxtend.frequent_patterns import apriori,association_rules
#       6 from mlxtend.preprocessing import TransactionEncoder
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
# Import Dataset
col_names = ['pur1','pur2','pur3','pur4','pur5','pur6','pur7','pur8','pur9','pur10','pur11','pur12','pur13','pur14','pur15','pur16','pur17','pur18','pur19','pur20','pur21','pur22','pur23','pur24','pur25','pur26','pur27','pur28','pur29','pur30','pur31','pur32']
groc=pd.read_csv('Database/groceries.csv', names=col_names)
groc
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13660/671499431.py in <module>
#       1 # Import Dataset
#       2 col_names = ['pur1','pur2','pur3','pur4','pur5','pur6','pur7','pur8','pur9','pur10','pur11','pur12','pur13','pur14','pur15','pur16','pur17','pur18','pur19','pur20','pur21','pur22','pur23','pur24','pur25','pur26','pur27','pur28','pur29','pur30','pur31','pur32']
# ----> 3 groc=pd.read_csv('Database/groceries.csv', names=col_names)
#       4 groc
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Database/groceries.csv'

# %%
groc.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13660/2699133734.py in <module>
# ----> 1 groc.shape
#
# NameError: name 'groc' is not defined

# %%
groc.dtypes

# %%
#Converting the data frame into a list of lists 
records = []
for i in range (0, 9835):
    records.append([str(groc.values[i,j]) for j in range(0, 32)])

# %%
records

# %%
# Using Transactionencoder to transform this dataset into a logical data frame
te=TransactionEncoder()

# %%
te_ary=te.fit_transform(records)
te_ary

# %%
# building the data frame rows are logical and columns are the items have been purchased 
te_df = pd.DataFrame(te_ary, columns = te.columns_)
te_df

# %%
# Print Column names
for col in te_df.columns:
    print(col)

# %%
# We need to drop nan column from the data frame
groc_clean = te_df.drop(['nan'], axis = 1)
groc_clean

# %%
# most popular items
count = groc_clean.loc[:,:].sum()
count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14164/4216355914.py in <module>
#       1 # most popular items
# ----> 2 count = groc_clean.loc[:,:].sum()
#       3 count
#
# NameError: name 'groc_clean' is not defined

# %%
# Top 10 Popular items
pop_item = count.sort_values(0, ascending = False).head(10)
pop_item
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14164/495512450.py in <module>
#       1 # Top 10 Popular items
# ----> 2 pop_item = count.sort_values(0, ascending = False).head(10)
#       3 pop_item
#
# NameError: name 'count' is not defined

# %%
pop_item = pop_item.to_frame().reset_index()
pop_item
# Out:
#               index     0
# 0        whole milk  2513
# 1  other vegetables  1903
# 2        rolls/buns  1809
# 3              soda  1715
# 4            yogurt  1372
# 5     bottled water  1087
# 6   root vegetables  1072
# 7    tropical fruit  1032
# 8     shopping bags   969
# 9           sausage   924

# %%
pop_item = pop_item.rename(columns = {'index': 'items',0: 'count'})
pop_item
# Out:
#               items  count
# 0        whole milk   2513
# 1  other vegetables   1903
# 2        rolls/buns   1809
# 3              soda   1715
# 4            yogurt   1372
# 5     bottled water   1087
# 6   root vegetables   1072
# 7    tropical fruit   1032
# 8     shopping bags    969
# 9           sausage    924

# %%
sns.barplot('count','items',data=pop_item)
# Out:
# C:\Users\Hitesh Koli\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Apriori Algorithm

# %% [markdown]
# ### 1. Association rules with 5% Support and 70% confidence

# %%
# With 5% Support
frequent_itemsets=apriori(groc_clean,min_support=0.05,use_colnames=True)
frequent_itemsets
# Out:
#      support                        itemsets
# 0   0.052466                          (beef)
# 1   0.080529                  (bottled beer)
# 2   0.110524                 (bottled water)
# 3   0.064870                   (brown bread)
# 4   0.055414                        (butter)
# 5   0.077682                   (canned beer)
# 6   0.082766                  (citrus fruit)
# 7   0.058058                        (coffee)
# 8   0.053279                          (curd)
# 9   0.063447                 (domestic eggs)
# 10  0.058973                   (frankfurter)
# 11  0.072293         (fruit/vegetable juice)
# 12  0.058566                     (margarine)
# 13  0.052364                       (napkins)
# 14  0.079817                    (newspapers)
# 15  0.193493              (other vegetables)
# 16  0.088968                        (pastry)
# 17  0.075648                     (pip fruit)
# 18  0.057651                          (pork)
# 19  0.183935                    (rolls/buns)
# 20  0.108998               (root vegetables)
# 21  0.093950                       (sausage)
# 22  0.098526                 (shopping bags)
# 23  0.174377                          (soda)
# 24  0.104931                (tropical fruit)
# 25  0.071683            (whipped/sour cream)
# 26  0.255516                    (whole milk)
# 27  0.139502                        (yogurt)
# 28  0.074835  (other vegetables, whole milk)
# 29  0.056634        (rolls/buns, whole milk)
# 30  0.056024            (whole milk, yogurt)

# %%
# with 70% confidence
rules=association_rules(frequent_itemsets,metric='lift',min_threshold=0.7)
rules
# Out:
#           antecedents         consequents  antecedent support  \
# 0  (other vegetables)        (whole milk)            0.193493
# 1        (whole milk)  (other vegetables)            0.255516
# 2        (rolls/buns)        (whole milk)            0.183935
# 3        (whole milk)        (rolls/buns)            0.255516
# 4        (whole milk)            (yogurt)            0.255516
# 5            (yogurt)        (whole milk)            0.139502
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.255516  0.074835    0.386758  1.513634  0.025394    1.214013
# 1            0.193493  0.074835    0.292877  1.513634  0.025394    1.140548
# 2            0.255516  0.056634    0.307905  1.205032  0.009636    1.075696
# 3            0.183935  0.056634    0.221647  1.205032  0.009636    1.048452
# 4            0.139502  0.056024    0.219260  1.571735  0.020379    1.102157
# 5            0.255516  0.056024    0.401603  1.571735  0.020379    1.244132

# %%
# visualization of obtained rule
plt.scatter(rules['support'],rules['confidence'])
plt.xlabel('support')
plt.ylabel('confidence') 
plt.show()

# %% [markdown]
# ### 2. Association rules with 1% Support and 80% confidence

# %%
# With 1% Support
frequent_itemsets2=apriori(groc_clean,min_support=0.01,use_colnames=True)
frequent_itemsets2
# Out:
#       support                                       itemsets
# 0    0.033452                                     (UHT-milk)
# 1    0.017692                                (baking powder)
# 2    0.052466                                         (beef)
# 3    0.033249                                      (berries)
# 4    0.026029                                    (beverages)
# ..        ...                                            ...
# 328  0.011998  (tropical fruit, root vegetables, whole milk)
# 329  0.014540          (root vegetables, whole milk, yogurt)
# 330  0.010473                     (soda, whole milk, yogurt)
# 331  0.015150           (tropical fruit, whole milk, yogurt)
# 332  0.010880       (whipped/sour cream, whole milk, yogurt)
#
# [333 rows x 2 columns]

# %%
# with 80% confidence
rules2=association_rules(frequent_itemsets2,metric='lift',min_threshold=0.8)
rules2
# Out:
#                       antecedents                       consequents  \
# 0              (other vegetables)                            (beef)
# 1                          (beef)                (other vegetables)
# 2                    (rolls/buns)                            (beef)
# 3                          (beef)                      (rolls/buns)
# 4                          (beef)                 (root vegetables)
# ..                            ...                               ...
# 611  (whipped/sour cream, yogurt)                      (whole milk)
# 612          (whole milk, yogurt)              (whipped/sour cream)
# 613          (whipped/sour cream)              (whole milk, yogurt)
# 614                  (whole milk)      (whipped/sour cream, yogurt)
# 615                      (yogurt)  (whipped/sour cream, whole milk)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.193493            0.052466  0.019725    0.101944  1.943066
# 1              0.052466            0.193493  0.019725    0.375969  1.943066
# 2              0.183935            0.052466  0.013625    0.074074  1.411858
# 3              0.052466            0.183935  0.013625    0.259690  1.411858
# 4              0.052466            0.108998  0.017387    0.331395  3.040367
# ..                  ...                 ...       ...         ...       ...
# 611            0.020742            0.255516  0.010880    0.524510  2.052747
# 612            0.056024            0.071683  0.010880    0.194192  2.709053
# 613            0.071683            0.056024  0.010880    0.151773  2.709053
# 614            0.255516            0.020742  0.010880    0.042579  2.052747
# 615            0.139502            0.032232  0.010880    0.077988  2.419607
#
#      leverage  conviction
# 0    0.009574    1.055095
# 1    0.009574    1.292416
# 2    0.003975    1.023337
# 3    0.003975    1.102329
# 4    0.011668    1.332628
# ..        ...         ...
# 611  0.005580    1.565719
# 612  0.006864    1.152033
# 613  0.006864    1.112881
# 614  0.005580    1.022807
# 615  0.006383    1.049627
#
# [616 rows x 9 columns]

# %%
rules2[rules2.lift>1]
# Out:
#                       antecedents                       consequents  \
# 0              (other vegetables)                            (beef)
# 1                          (beef)                (other vegetables)
# 2                    (rolls/buns)                            (beef)
# 3                          (beef)                      (rolls/buns)
# 4                          (beef)                 (root vegetables)
# ..                            ...                               ...
# 611  (whipped/sour cream, yogurt)                      (whole milk)
# 612          (whole milk, yogurt)              (whipped/sour cream)
# 613          (whipped/sour cream)              (whole milk, yogurt)
# 614                  (whole milk)      (whipped/sour cream, yogurt)
# 615                      (yogurt)  (whipped/sour cream, whole milk)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.193493            0.052466  0.019725    0.101944  1.943066
# 1              0.052466            0.193493  0.019725    0.375969  1.943066
# 2              0.183935            0.052466  0.013625    0.074074  1.411858
# 3              0.052466            0.183935  0.013625    0.259690  1.411858
# 4              0.052466            0.108998  0.017387    0.331395  3.040367
# ..                  ...                 ...       ...         ...       ...
# 611            0.020742            0.255516  0.010880    0.524510  2.052747
# 612            0.056024            0.071683  0.010880    0.194192  2.709053
# 613            0.071683            0.056024  0.010880    0.151773  2.709053
# 614            0.255516            0.020742  0.010880    0.042579  2.052747
# 615            0.139502            0.032232  0.010880    0.077988  2.419607
#
#      leverage  conviction
# 0    0.009574    1.055095
# 1    0.009574    1.292416
# 2    0.003975    1.023337
# 3    0.003975    1.102329
# 4    0.011668    1.332628
# ..        ...         ...
# 611  0.005580    1.565719
# 612  0.006864    1.152033
# 613  0.006864    1.112881
# 614  0.005580    1.022807
# 615  0.006383    1.049627
#
# [598 rows x 9 columns]

# %%
# visualization of obtained rule
plt.scatter(rules2['support'],rules2['confidence'])
plt.xlabel('support')
plt.ylabel('confidence') 
plt.show()
